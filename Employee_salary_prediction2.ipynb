# %%
import pandas as pd
data = pd.read_csv("/content/Dataset09-Employee-salary-prediction.csv")

# %%
data
# Out:
#       Age  Gender Education Level                      Job Title  \
# 0    32.0    Male      Bachelor's              Software Engineer
# 1    28.0  Female        Master's                   Data Analyst
# 2    45.0    Male             PhD                 Senior Manager
# 3    36.0  Female      Bachelor's                Sales Associate
# 4    52.0    Male        Master's                       Director
# ..    ...     ...             ...                            ...
# 370  35.0  Female      Bachelor's       Senior Marketing Analyst
# 371  43.0    Male        Master's         Director of Operations
# 372  29.0  Female      Bachelor's         Junior Project Manager
# 373  34.0    Male      Bachelor's  Senior Operations Coordinator
# 374  44.0  Female             PhD        Senior Business Analyst
#
#      Years of Experience    Salary
# 0                    5.0   90000.0
# 1                    3.0   65000.0
# 2                   15.0  150000.0
# 3                    7.0   60000.0
# ...

# %%
data.dtypes
# Out:
# Age                    float64
# Gender                  object
# Education Level         object
# Job Title               object
# Years of Experience    float64
# Salary                 float64
# dtype: object

# %%
data[data.duplicated()]
# Out:
#       Age  Gender Education Level                              Job Title  \
# 195  28.0    Male      Bachelor's                Junior Business Analyst
# 250  30.0  Female      Bachelor's           Junior Marketing Coordinator
# 251  38.0    Male        Master's                   Senior IT Consultant
# 252  45.0  Female             PhD                Senior Product Designer
# 253  28.0    Male      Bachelor's  Junior Business Development Associate
# 254  35.0  Female      Bachelor's               Senior Marketing Analyst
# 255  44.0    Male      Bachelor's               Senior Software Engineer
# 256  34.0  Female        Master's               Senior Financial Advisor
# 257  35.0    Male      Bachelor's             Senior Project Coordinator
# 258  50.0  Female             PhD                 Director of Operations
# 260   NaN     NaN             NaN                                    NaN
# 262  46.0    Male             PhD                  Senior Data Scientist
# ...

# %%
data=data.drop_duplicates(keep='first')

# %%
data.isna()
# Out:
#        Age  Gender  Education Level  Job Title  Years of Experience  Salary
# 0    False   False            False      False                False   False
# 1    False   False            False      False                False   False
# 2    False   False            False      False                False   False
# 3    False   False            False      False                False   False
# 4    False   False            False      False                False   False
# ..     ...     ...              ...        ...                  ...     ...
# 348  False   False            False      False                False   False
# 349  False   False            False      False                False   False
# 350  False   False            False      False                False   False
# 351  False   False            False      False                False   False
# 371  False   False            False      False                False   False
#
# [325 rows x 6 columns]

# %%
data.isna().sum()
# Out:
# Age                    1
# Gender                 1
# Education Level        1
# Job Title              1
# Years of Experience    1
# Salary                 1
# dtype: int64

# %%
data.dropna(how='any',inplace=True)
# Out:
# /tmp/ipython-input-9-3923625894.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.dropna(how='any',inplace=True)

# %%
data['Age'].value_counts()
# Out:
# Age
# 29.0    20
# 33.0    19
# 36.0    18
# 31.0    18
# 44.0    15
# 45.0    14
# 35.0    14
# 34.0    14
# 30.0    14
# 47.0    13
# 39.0    12
# 40.0    12
# 38.0    12
# 37.0    12
# 32.0    12
# 42.0    11
# 28.0    11
# 43.0    11
# 41.0    10
# 46.0     9
# 27.0     9
# 48.0     8
# 26.0     7
# 49.0     7
# 50.0     7
# 51.0     5
# 25.0     4
# 52.0     3
# 24.0     1
# 23.0     1
# 53.0     1
# Name: count, dtype: int64

# %%
data['Age'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Age'>

# %%
data['Gender'].value_counts()
# Out:
# Gender
# Male      170
# Female    154
# Name: count, dtype: int64

# %%
data['Gender'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Gender'>

# %%
data['Education Level'].value_counts()
# Out:
# Education Level
# Bachelor's    191
# Master's       91
# PhD            42
# Name: count, dtype: int64

# %%
data['Education Level'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Education Level'>

# %%
data['Job Title'].value_counts()
# Out:
# Job Title
# Director of Operations            9
# Director of Marketing             8
# Senior Marketing Manager          8
# Senior Project Manager            7
# Senior Data Scientist             6
#                                  ..
# Junior Social Media Specialist    1
# Junior Operations Coordinator     1
# Senior HR Specialist              1
# Director of HR                    1
# Junior Financial Advisor          1
# Name: count, Length: 174, dtype: int64

# %%
data['Years of Experience'].value_counts()
# Out:
# Years of Experience
# 3.0     27
# 2.0     26
# 9.0     19
# 8.0     17
# 10.0    16
# 4.0     16
# 7.0     16
# 5.0     16
# 16.0    15
# 12.0    14
# 19.0    13
# 20.0    13
# 15.0    12
# 21.0    11
# 18.0    11
# 6.0     11
# 14.0    11
# 1.5     11
# 13.0    10
# 11.0     9
# 22.0     8
# 1.0      7
# 17.0     5
# 0.0      3
# 25.0     3
# 23.0     2
# 24.0     1
# 0.5      1
# Name: count, dtype: int64

# %%
data['Years of Experience'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Years of Experience'>

# %%
data['Salary'].value_counts()
# Out:
# Salary
# 40000.0     26
# 120000.0    20
# 50000.0     19
# 45000.0     18
# 95000.0     18
# 180000.0    17
# 90000.0     15
# 140000.0    14
# 160000.0    14
# 110000.0    14
# 60000.0     13
# 170000.0    13
# 100000.0    12
# 150000.0    12
# 35000.0     12
# 80000.0     12
# 130000.0    11
# 55000.0     10
# 65000.0      9
# 70000.0      8
# 105000.0     6
# 85000.0      5
# 75000.0      4
# 190000.0     4
# 115000.0     3
# 200000.0     2
# 135000.0     2
# 250000.0     2
# 175000.0     2
# 125000.0     1
# 30000.0      1
# 220000.0     1
# 185000.0     1
# 145000.0     1
# 155000.0     1
# 350.0        1
# Name: count, dtype: int64

# %%
data['Salary'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Salary'>

# %%
import matplotlib.pyplot as plt
plt.boxplot(data['Age'])
plt.show()

# %%
import matplotlib.pyplot as plt
plt.boxplot(data['Salary'])
plt.show()

# %%
from sklearn.preprocessing import LabelEncoder
encoder=LabelEncoder()
data['Gender_Encode']=encoder.fit_transform(data['Gender'])
data['Job Title_Encode']=encoder.fit_transform(data['Job Title'])
data['Education Level_Encode']=encoder.fit_transform(data['Education Level'])
data
# Out:
# /tmp/ipython-input-23-288596187.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Gender_Encode']=encoder.fit_transform(data['Gender'])
# /tmp/ipython-input-23-288596187.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Job Title_Encode']=encoder.fit_transform(data['Job Title'])
# /tmp/ipython-input-23-288596187.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
x = data.drop(columns=['Salary', 'Gender', 'Education Level', 'Job Title'])
y = data['Salary']
x
# Out:
#       Age  Years of Experience  Gender_Encode  Job Title_Encode  \
# 0    32.0                  5.0              1               159
# 1    28.0                  3.0              0                17
# 2    45.0                 15.0              1               130
# 3    36.0                  7.0              0               101
# 4    52.0                 20.0              1                22
# ..    ...                  ...            ...               ...
# 348  28.0                  1.0              0                68
# 349  36.0                  8.0              1               111
# 350  44.0                 16.0              0               115
# 351  31.0                  3.0              1                63
# 371  43.0                 19.0              1                30
#
#      Education Level_Encode
# 0                         0
# 1                         1
# 2                         2
# 3                         0
# 4                         1
# ...

# %%
y
# Out:
# 0       90000.0
# 1       65000.0
# 2      150000.0
# 3       60000.0
# 4      200000.0
#          ...
# 348     35000.0
# 349    110000.0
# 350    160000.0
# 351     55000.0
# 371    170000.0
# Name: Salary, Length: 324, dtype: float64

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
data['Age_scaled']=scaler.fit_transform(data[['Age']])
data['Experience_scaled']=scaler.fit_transform(data[['Years of Experience']])
data
# Out:
# /tmp/ipython-input-26-3142573040.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Age_scaled']=scaler.fit_transform(data[['Age']])
# /tmp/ipython-input-26-3142573040.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Experience_scaled']=scaler.fit_transform(data[['Years of Experience']])
#       Age  Gender Education Level                            Job Title  \
# 0    32.0    Male      Bachelor's                    Software Engineer
# ...

# %%
data.head()
# Out:
#     Age  Gender Education Level          Job Title  Years of Experience  \
# 0  32.0    Male      Bachelor's  Software Engineer                  5.0
# 1  28.0  Female        Master's       Data Analyst                  3.0
# 2  45.0    Male             PhD     Senior Manager                 15.0
# 3  36.0  Female      Bachelor's    Sales Associate                  7.0
# 4  52.0    Male        Master's           Director                 20.0
#
#      Salary  Gender_Encode  Job Title_Encode  Education Level_Encode  \
# 0   90000.0              1               159                       0
# 1   65000.0              0                17                       1
# 2  150000.0              1               130                       2
# 3   60000.0              0               101                       0
# 4  200000.0              1                22                       1
#
#    Age_scaled  Experience_scaled
# 0   -0.750231          -0.761821
# 1   -1.307742          -1.063017
# ...

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=23)

# %%
x_train
# Out:
#       Age  Years of Experience  Gender_Encode  Job Title_Encode  \
# 206  31.0                  4.0              1                61
# 271  32.0                  4.0              0                64
# 28   43.0                 15.0              0               112
# 321  32.0                  4.0              1                58
# 351  31.0                  3.0              1                63
# ..    ...                  ...            ...               ...
# 239  39.0                 10.0              1               135
# 31   31.0                  4.0              0                 1
# 40   34.0                  5.0              0               169
# 232  27.0                  1.5              0                72
# 83   52.0                 24.0              1                 8
#
#      Education Level_Encode
# 206                       0
# 271                       0
# 28                        2
# 321                       0
# 351                       0
# ...

# %%
x_train.shape
# Out:
# (259, 5)

# %%
x_test.shape
# Out:
# (65, 5)

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
predict1=lr.predict(x_test)
predict1
# Out:
# array([ 79202.35566217, 160463.66754035,  52347.0138401 ,  21443.26915791,
#         40235.29037668,  96063.11050049,  76425.1355632 , 157443.07929759,
#         84598.70901503, 149916.4339694 ,  47746.20720029, 125940.17738276,
#         43128.23586445, 148275.62676617,  90162.11320091, 123935.40201213,
#         54801.45089118, 107376.32365716, 130611.36404467,  99795.02681145,
#        123339.40547841, 100060.4131268 , 150758.31865151, 155869.37577795,
#         37074.37873292,  82662.58915905,  35880.65009998, 141108.24034493,
#         42115.74906561, 117483.66233474,  48412.35527618,  90182.99455504,
#         88243.38325139,  80127.95276474,  97684.48264232,  80138.13456545,
#        151154.89900556,  27152.84282268,  52172.75490133,  65301.81863911,
#         60549.29581655, 108738.46515098, 144144.21624224,  58279.07429452,
#        151377.38579521,  83947.67037899,  94662.5323717 , 149956.00742181,
# ...

# %%
df=pd.DataFrame({'Actual':y_test,'Predicted':predict1})
df
# Out:
#        Actual      Predicted
# 184   85000.0   79202.355662
# 2    150000.0  160463.667540
# 131   45000.0   52347.013840
# 18    35000.0   21443.269158
# 336   40000.0   40235.290377
# ..        ...            ...
# 338  150000.0  147670.067496
# 344  160000.0  150403.170257
# 203   45000.0   45688.350503
# 327   55000.0   61318.189261
# 10    75000.0   66810.956840
#
# [65 rows x 2 columns]

# %%
from sklearn.metrics import accuracy_score, r2_score, mean_squared_error
import numpy as np
r2_score(y_test,predict1)
# Out:
# 0.8960160091843488

# %%
round(mean_squared_error(y_test,predict1),2)
# Out:
# 213665565.98

# %%
data.head()
# Out:
#     Age  Gender Education Level          Job Title  Years of Experience  \
# 0  32.0    Male      Bachelor's  Software Engineer                  5.0
# 1  28.0  Female        Master's       Data Analyst                  3.0
# 2  45.0    Male             PhD     Senior Manager                 15.0
# 3  36.0  Female      Bachelor's    Sales Associate                  7.0
# 4  52.0    Male        Master's           Director                 20.0
#
#      Salary  Gender_Encode  Job Title_Encode  Education Level_Encode  \
# 0   90000.0              1               159                       0
# 1   65000.0              0                17                       1
# 2  150000.0              1               130                       2
# 3   60000.0              0               101                       0
# 4  200000.0              1                22                       1
#
#    Age_scaled  Experience_scaled
# 0   -0.750231          -0.761821
# 1   -1.307742          -1.063017
# ...

# %%
age = 49
experience = 5
gender = 1
education_level = 0
job_title = 159
scaled_age = scaler.transform([[age]])[0][0]
scaled_experience = scaler.transform([[experience]])[0][0]
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
scaler.transform([[15]])[0][0]
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# np.float64(0.7441581452572275)

# %%
import numpy as np
Empsal = np.array([[scaled_age, gender, education_level, job_title, scaled_experience]])
predictedsal = lr.predict(Empsal)
predictedsal
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([-42078.84678192])
